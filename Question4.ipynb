# %%
#importing data into a data frame
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('AfghanistanDataset.xlsx', sheet_name = "January Total") # df means dataframe

# print whole sheet data
print(df)

print("Line graph:  ") 
plt.plot(df["Days"], df["confirmed"]) 
plt.title('Daily Afghanistan covid confirmed cases (1/01/2021-31/01/2021)')
plt.xlabel('Day')
plt.ylabel('Number of Confirmed Cases')
plt.show()

print("Line graph:  ") 
plt.plot(df["Days"], df["deaths"]) 
plt.title('Daily Afghanistan covid deaths (1/01/2021-31/01/2021)')
plt.xlabel('Day')
plt.ylabel('Number of Deaths')
plt.show()

print("Line graph:  ") 
plt.plot(df["Days"], df["recovered"]) 
plt.title('Daily Afghanistan covid recovered cases (1/01/2021-31/01/2021)')
plt.xlabel('Day')
plt.ylabel('Number of Recovered Cases')
plt.show()
# Out:
#          Days  confirmed  deaths  recovered
# 0  2021-01-01      52513    2201      41727
# 1  2021-01-02      52586    2211      41727
# 2  2021-01-03      52709    2221      41727
# 3  2021-01-04      52909    2230      42530
# 4  2021-01-05      52011    2237      42666
# 5  2021-01-06      53105    2244      42666
# 6  2021-01-07      53207    2253      43291
# 7  2021-01-08      53332    2257      43440
# 8  2021-01-09      53400    2264      43740
# 9  2021-01-10      53489    2277      43948
# 10 2021-01-11      53538    2288      44137
# 11 2021-01-12      53584    2301      44608
# 12 2021-01-13      53690    2308      44850
# 13 2021-01-14      53775    2314      45298
# 14 2021-01-15      53831    2324      45434
# 15 2021-01-16      53938    2336      45465
# 16 2021-01-17      53984    2339      45868
# 17 2021-01-18      54062    2343      46359
# 18 2021-01-19      54141    2346      46554
# 19 2021-01-20      54278    2354      46759
# ...

# %%
#importing data into a data frame
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('AfghanistanDataset.xlsx', sheet_name = "June Total") # df means dataframe

# print whole sheet data
print(df)

print("Line graph:  ") 
plt.plot(df["Days"], df["confirmed"]) 
plt.title('Daily Afghanistan covid confirmed cases (1/06/2021-30/06/2021)')
plt.xlabel('Day')
plt.ylabel('Number of Confirmed Cases')
plt.show()

print("Line graph:  ") 
plt.plot(df["Days"], df["deaths"]) 
plt.title('Daily Afghanistan covid deaths (1/06/2021-30/06/2021)')
plt.xlabel('Day')
plt.ylabel('Number of Deaths')
plt.show()

print("Line graph:  ") 
plt.plot(df["Days"], df["recovered"]) 
plt.title('Daily Afghanistan covid recovered cases (1/06/2021-30/06/2021)')
plt.xlabel('Day')
plt.ylabel('Number of Recovered Cases')
plt.show()
# Out:
#          Days  confirmed  deaths  recovered
# 0  2021-06-01      72977    2973      57741
# 1  2021-06-02      74026    3007      57963
# 2  2021-06-03      75119    3034      58070
# 3  2021-06-04      76628    3068      58144
# 4  2021-06-05      77963    3104      58265
# 5  2021-06-06      79224    3145      58622
# 6  2021-06-07      80841    3187      58998
# 7  2021-06-08      82326    3251      59569
# 8  2021-06-09      84050    3305      59871
# 9  2021-06-10      85892    3356      60280
# 10 2021-06-11      87716    3412      60598
# 11 2021-06-12      88740    3449      60939
# 12 2021-06-13      89861    3527      61410
# 13 2021-06-14      91458    3612      61706
# 14 2021-06-15      93272    3683      61820
# 15 2021-06-16      93288    3683      62397
# 16 2021-06-17      96531    3842      62698
# 17 2021-06-18      98734    3934      63426
# 18 2021-06-19     100521    4030      63875
# 19 2021-06-20     101906    4122      64401
# ...

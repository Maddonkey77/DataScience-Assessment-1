# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import glob
import os
print('modules are imported')
# Out:
# modules are imported

# %%
directory = '/Users/test/Library/CloudStorage/OneDrive-UniversityofKent/MAST4016 Data Science Practice/Assessment 2/covid-19-reports-jan-2020'
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        with open(os.path.join(directory,filename)) as f:
            df = pd.read_csv(filename)
            df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/test/Library/CloudStorage/OneDrive-UniversityofKent/MAST4016 Data Science Practice/Assessment 2/test.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/Users/test/Library/CloudStorage/OneDrive-UniversityofKent/MAST4016%20Data%20Science%20Practice/Assessment%202/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> if filename.endswith('.csv'):
#       <a href='vscode-notebook-cell:/Users/test/Library/CloudStorage/OneDrive-UniversityofKent/MAST4016%20Data%20Science%20Practice/Assessment%202/test.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>     with open(os.path.join(directory,filename)) as f:
# ----> <a href='vscode-notebook-cell:/Users/test/Library/CloudStorage/OneDrive-UniversityofKent/MAST4016%20Data%20Science%20Practice/Assessment%202/test.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>         df = pd.read_csv(filename)
#       <a href='vscode-notebook-cell:/Users/test/Library/CloudStorage/OneDrive-UniversityofKent/MAST4016%20Data%20Science%20Practice/Assessment%202/test.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>         df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '01-31-2020.csv'

# %%
list(df.columns)
# Out:
# ['Province/State',
#  'Country/Region',
#  'Last Update',
#  'Confirmed',
#  'Deaths',
#  'Recovered']

# %%
result = df[df["Country/Region"] == 'Mainland China']
result
# Out:
#     Province/State  Country/Region    Last Update  Confirmed  Deaths  \
# 0            Hubei  Mainland China  1/25/20 17:00      761.0    40.0
# 1        Guangdong  Mainland China  1/25/20 17:00       78.0     NaN
# 2         Zhejiang  Mainland China  1/25/20 17:00       62.0     NaN
# 3        Chongqing  Mainland China  1/25/20 17:00       57.0     NaN
# 4            Hunan  Mainland China  1/25/20 17:00       43.0     NaN
# 5          Beijing  Mainland China  1/25/20 17:00       41.0     NaN
# 6            Anhui  Mainland China  1/25/20 17:00       39.0     NaN
# 7         Shanghai  Mainland China  1/25/20 17:00       33.0     NaN
# 8            Henan  Mainland China  1/25/20 17:00       32.0     NaN
# 9          Sichuan  Mainland China  1/25/20 17:00       28.0     NaN
# 10        Shandong  Mainland China  1/25/20 17:00       27.0     NaN
# 11         Guangxi  Mainland China  1/25/20 17:00       23.0     NaN
# 12          Hainan  Mainland China  1/25/20 17:00       19.0     NaN
# 13         Jiangxi  Mainland China  1/25/20 17:00       18.0     NaN
# 14          Fujian  Mainland China  1/25/20 17:00       18.0     NaN
# 15         Jiangsu  Mainland China  1/25/20 17:00       18.0     NaN
# 16        Liaoning  Mainland China  1/25/20 17:00       17.0     NaN
# 17         Shaanxi  Mainland China  1/25/20 17:00       15.0     NaN
# 18          Yunnan  Mainland China  1/25/20 17:00       11.0     NaN
# 19         Tianjin  Mainland China  1/25/20 17:00       10.0     NaN
# 20    Heilongjiang  Mainland China  1/25/20 17:00        9.0     1.0
# 21           Hebei  Mainland China  1/25/20 17:00        8.0     1.0
# 22  Inner Mongolia  Mainland China  1/25/20 17:00        7.0     NaN
# 23          Shanxi  Mainland China  1/25/20 17:00        6.0     NaN
# 25         Guizhou  Mainland China  1/25/20 17:00        4.0     NaN
# 26           Jilin  Mainland China  1/25/20 17:00        4.0     NaN
# 27           Gansu  Mainland China  1/25/20 17:00        4.0     NaN
# 28         Ningxia  Mainland China  1/25/20 17:00        3.0     NaN
# 30        Xinjiang  Mainland China  1/25/20 17:00        3.0     NaN
# 32         Qinghai  Mainland China  1/25/20 17:00        1.0     NaN
#
#     Recovered
# 0        32.0
# 1         2.0
# 2         1.0
# 3         NaN
# 4         NaN
# 5         2.0
# 6         NaN
# 7         1.0
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        1.0
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 30        NaN
# 32        NaN

# %%
total_confirmed = result['Confirmed'].sum()
total_deaths = result['Deaths'].sum()
total_recovered = result['Recovered'].sum()
print('Confirmed: ',total_confirmed)
print('Deaths: ',total_deaths)
print('Recovered: ',total_recovered)
# Out:
# Confirmed:  1399.0
# Deaths:  42.0
# Recovered:  39.0

# %%
#importing data into a data frame
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('cases.xlsx', sheet_name = "Deaths2023") # df means dataframe

# print whole sheet data
print(df)
# Out:
#     Day  England  Scotland  Northern Ireland  Wales  Unnamed: 5  Total UK
# 0     1      111        10                 2      9         NaN       132
# 1     2      107        12                 4      7         NaN       130
# 2     3      114        15                 2      8         NaN       139
# 3     4      117        15                 0      9         NaN       141
# 4     5      115        15                 6     10         NaN       146
# 5     6       88        14                 7      7         NaN       116
# 6     7       99        14                 3      5         NaN       121
# 7     8      103        11                 3      8         NaN       125
# 8     9      108        17                 3      5         NaN       133
# 9    10       87        11                 2     17         NaN       117
# 10   11       77        13                 3      4         NaN        97
# 11   12      103         5                 6      5         NaN       119
# ...

# %%
# deaths
print("Line graph:  ") 
plt.plot(df["Day"], df["Total UK"]) 
plt.title('Daily total UK covid death cases (01-31 January 2023)')
plt.xlabel('Day')
plt.ylabel('Number of Deaths')
plt.show()
# Out:
# Line graph:

# %%
confirmeddf = pd.read_excel('cases.xlsx', sheet_name = "Confirmed2023") # df means dataframe

# print whole sheet data
print(confirmeddf)
# Out:
#     Day  England  Scotland  Northern Ireland  Wales  Unnamed: 5  Total UK
# 0     1     3338       265              5385     60         NaN      9048
# 1     2     4636       332              6192     89         NaN     11249
# 2     3     5739       409              7309    112         NaN     13569
# 3     4     5009       479              8470    102         NaN     14060
# 4     5     4168       422              6819     93         NaN     11502
# 5     6     3412       362              3578     76         NaN      7428
# 6     7     2417       274              2708     41         NaN      5440
# 7     8     2501       272              2637     48         NaN      5458
# 8     9     3212       335              2838     59         NaN      6444
# 9    10     2803       244              3614     71         NaN      6732
# 10   11     2373       234              3232     38         NaN      5877
# 11   12     2204       219              3130     57         NaN      5610
# ...

# %%
#confirmed cases
print("Line Plot:  ") 
plt.plot(confirmeddf["Day"], confirmeddf["Total UK"]) 
plt.title('Daily Total UK covid confirmed cases (01-31 January 2023)')
plt.xlabel('Day')
plt.ylabel('Number of Cases')
plt.show()
# Out:
# Line Plot:

# %%
#US
us_df = pd.read_excel('cases.xlsx', sheet_name = "UScases2023") # df means dataframe

# print whole sheet data
print(us_df)
# Out:
#          Date  Confirmed   Deaths  Recovered
# 0  2023-01-01  100769543  1092779          0
# 1  2023-01-02  100777853  1092801          0
# 2  2023-01-03  100890152  1093208          0
# 3  2023-01-04  101088268  1094493          0
# 4  2023-01-05  101196118  1095335          0
# 5  2023-01-06  101261306  1095789          0
# 6  2023-01-07  101267161  1095815          0
# 7  2023-01-08  101272871  1095832          0
# 8  2023-01-09  101315882  1096132          0
# 9  2023-01-10  101399167  1097024          0
# 10 2023-01-11  101538785  1098854          0
# 11 2023-01-12  101603765  1099574          0
# 12 2023-01-13  101637080  1099954          0
# 13 2023-01-14  101642365  1100006          0
# 14 2023-01-15  101645683  1100023          0
# 15 2023-01-16  101653200  1100068          0
# 16 2023-01-17  101734455  1100812          0
# 17 2023-01-18  101863085  1102393          0
# 18 2023-01-19  101954273  1103712          0
# 19 2023-01-20  101991792  1104154          0
# ...

# %%
print("Line Plot:  ") 
plt.plot(us_df['Date'], us_df['Confirmed']) 
plt.title('Daily Total US covid confirmed cases (01-31 January 2023)')
plt.xlabel('Day')
plt.ylabel('Number of Cases')
plt.show()
# Out:
# Line Plot:

# %%
print("Line Plot:  ") 
plt.plot(us_df['Date'], us_df['Deaths']) 
plt.title('Daily Total US covid death cases (01-31 January 2023)')
plt.xlabel('Day')
plt.ylabel('Number of deaths')
plt.show()
# Out:
# Line Plot:
